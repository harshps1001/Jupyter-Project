# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# My name is 𝗛𝗮𝗿𝘀𝗵𝗽𝗿𝗲𝗲𝘁.
# I am currently a student.

# %% [markdown]
# 𝘐 𝘢𝘮 𝘪𝘯𝘵𝘦𝘳𝘦𝘴𝘵𝘦𝘥 𝘪𝘯 𝘋𝘢𝘵𝘢 𝘚𝘤𝘪𝘦𝘯𝘤𝘦 𝘢𝘴 𝘪𝘵 𝘢 𝘧𝘶𝘵𝘶𝘳𝘦 𝘰𝘳𝘪𝘦𝘯𝘵𝘦𝘥 𝘱𝘳𝘰𝘧𝘦𝘴𝘴𝘪𝘰𝘯 𝘵𝘩𝘢𝘵 𝘤𝘢𝘯 𝘣𝘦 𝘢 𝘳𝘰𝘰𝘵 𝘧𝘰𝘳 𝘮𝘢𝘵𝘦𝘳𝘪𝘢𝘭 𝘤𝘩𝘢𝘯𝘨𝘦 𝘢𝘯𝘥 𝘪𝘯𝘯𝘰𝘷𝘢𝘵𝘪𝘰𝘯

# %% [markdown]
# Cell 5 is supposed to perform basic arithematic functions of the given numbers:

# %%
1+1
# Out:
# 2

# %% [markdown]
# List is as follows
# 1. IBM Cloud
# 2. Watson Studio
# 3. Jupyter Notebook
#
#
# ![Screenshot%202022-09-08%20142517.jpg](attachment:Screenshot%202022-09-08%20142517.jpg)
